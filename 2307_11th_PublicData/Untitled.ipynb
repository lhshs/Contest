# %%
import pandas as pd

# %%
a = pd.read_csv('G:/내 드라이브/취업/Contest/2307_PublicData/data/단기육상예보.csv', sep=',')
b = pd.read_csv('G:/내 드라이브/취업/Contest/2307_PublicData/data/단기해상예보.csv', sep=',')
c = pd.read_csv('G:/내 드라이브/취업/Contest/2307_PublicData/data/우리나라영향태풍_2018.csv', sep=',')
d = pd.read_csv('G:/내 드라이브/취업/Contest/2307_PublicData/data/우리나라영향태풍_2019.csv', sep=',')
e = pd.read_csv('G:/내 드라이브/취업/Contest/2307_PublicData/data/우리나라영향태풍_2020.csv', sep=',')
f = pd.read_csv('G:/내 드라이브/취업/Contest/2307_PublicData/data/우리나라영향태풍_2021.csv', sep=',')
g = pd.read_csv('G:/내 드라이브/취업/Contest/2307_PublicData/data/적설관측자료(2023).csv', sep=',')
h = pd.read_csv('G:/내 드라이브/취업/Contest/2307_PublicData/data/중기기온예보.csv', sep=',')
i = pd.read_csv('G:/내 드라이브/취업/Contest/2307_PublicData/data/중기육상예보.csv', sep=',')
j = pd.read_csv('G:/내 드라이브/취업/Contest/2307_PublicData/data/중기해상예보.csv', sep=',')
k = pd.read_csv('G:/내 드라이브/취업/Contest/2307_PublicData/data/특보자료.csv', sep=',')

# %%
a
# Out:
#          Unnamed: 0    REG_ID         TM_FC         TM_EF  MOD  NE  STN  C  \
# 0                 0  11A00101  202206010500  202206010000  A02   0  109  2
# 1                 1  11A00101  202206010500  202206011200  A02   1  109  2
# 2                 2  11A00101  202206010500  202206020000  A02   2  109  2
# 3                 3  11A00101  202206010500  202206021200  A02   3  109  2
# 4                 4  11A00101  202206010500  202206030000  A02   4  109  2
# ...             ...       ...           ...           ...  ...  ..  ... ..
# 1244460     1244460  11K20005  202302131700  202302150000  A02   3  107  2
# 1244461     1244461  11K20005  202302131700  202302151200  A02   4  107  2
# 1244462     1244462  11K20005  202302131700  202302160000  A02   5  107  2
# 1244463     1244463  11K20005  202302131700  202302161200  A02   6  107  2
# 1244464     1244464  11K20005  202302131700  202302170000  A02   7  107  2
#
#         MAN_ID MAN_FC  W1  T  W2  TA  ST   SKY  PREP         WF
# ...

# %%
g
# Out:
#         Unnamed: 0    YYMMDDHHMI   STN STN.1        LON       LAT     STN.2  \
# 0                0  202301010000    90    속초  128.56473  38.25085  000-----
# 1                1  202301010100    90    속초  128.56473  38.25085  000-----
# 2                2  202301010200    90    속초  128.56473  38.25085  000-----
# 3                3  202301010300    90    속초  128.56473  38.25085  000-----
# 4                4  202301010400    90    속초  128.56473  38.25085  000-----
# ...            ...           ...   ...   ...        ...       ...       ...
# 787705      787705  202303122000  5343    포항  129.37963  36.03259  000-----
# 787706      787706  202303122100  5343    포항  129.37963  36.03259  000-----
# 787707      787707  202303122200  5343    포항  129.37963  36.03259  000-----
# 787708      787708  202303122300  5343    포항  129.37963  36.03259  000-----
# 787709      787709  202303130000  5343    포항  129.37963  36.03259  000-----
#
# ...

# %%
g[g['YYMMDDHHMI'] == 202301030000]
# Out:
#         Unnamed: 0    YYMMDDHHMI   STN STN.1         LON        LAT     STN.2  \
# 48              48  202301030000    90    속초  128.564730  38.250850  000-----
# 1753          1753  202301030000    93   북춘천  127.754430  37.947380  000-----
# 3458          3458  202301030000    95    철원  127.304200  38.147870  000-----
# 5163          5163  202301030000    98   동두천  127.060690  37.901860  000-----
# 6868          6868  202301030000    99    파주  126.766490  37.885880  000-----
# ...            ...           ...   ...   ...         ...        ...       ...
# 779233      779233  202301030000   990    낙천  126.230530  33.318210  000-----
# 780938      780938  202301030000   991    옥포  128.445620  35.802790  000-----
# 782643      782643  202301030000   992    하빈  128.446400  35.906200  000-----
# 784348      784348  202301030000   994    심포  126.642112  35.854464  000-----
# 786053      786053  202301030000  5343    포항  129.379630  36.032590  000-----
#
# ...

# %%
# g['STN.1'].value_counts()
# g.describe()
# Out:
#           Unnamed: 0    YYMMDDHHMI            STN            LON  \
# count  787710.000000  7.877100e+05  787710.000000  787710.000000
# mean   393854.500000  2.023019e+11     597.032468     127.212694
# std    227392.434609  7.058224e+05     336.450156       6.385347
# min         0.000000  2.023010e+11      90.000000      27.972420
# 25%    196927.250000  2.023012e+11     329.000000     126.815740
# 50%    393854.500000  2.023021e+11     627.500000     127.471775
# 75%    590781.750000  2.023022e+11     803.000000     128.460600
# max    787709.000000  2.023031e+11    5343.000000     130.898640
#
#                  LAT         SD_TOT         SD_DAY         SD_HR3  \
# count  787710.000000  787710.000000  787710.000000  787710.000000
# mean       36.211299    -977.698156    -997.421608    -998.525262
# std         1.290808     144.696037      39.735731      21.782104
# min        33.173317    -999.000000    -999.000000    -999.000000
# ...

# %%
h[h['TM_FC'] == 202206010600]
# Out:
#       Unnamed: 0    REG_ID         TM_FC         TM_EF  MOD  STN  C   MIN  \
# 0              0  11A00101  202206010600  202206040000  A01  109  2  15.0
# 1              1  11A00101  202206010600  202206050000  A01  109  2  16.0
# 2              2  11A00101  202206010600  202206060000  A01  109  2  14.0
# 3              3  11A00101  202206010600  202206070000  A01  109  2  14.0
# 4              4  11A00101  202206010600  202206080000  A01  109  2  14.0
# ...          ...       ...           ...           ...  ...  ... ..   ...
# 1603        1603  21F20804  202206010600  202206070000  A01  156  5  14.0
# 1604        1604  21F20804  202206010600  202206080000  A01  156  5  14.0
# 1605        1605  21F20804  202206010600  202206090000  A01  156  5  15.0
# 1606        1606  21F20804  202206010600  202206100000  A01  156  5  15.0
# 1607        1607  21F20804  202206010600  202206110000  A01  156  5  17.0
#
#        MAX  MIN_L  MIN_H  MAX_L  MAX_H
# 0     20.0      1      1      2      1
# ...

# %%
# 단기
a[a['TM_FC'] == 202206010500]
# Out:
#       Unnamed: 0    REG_ID         TM_FC         TM_EF  MOD  NE  STN  C  \
# 0              0  11A00101  202206010500  202206010000  A02   0  109  2
# 1              1  11A00101  202206010500  202206011200  A02   1  109  2
# 2              2  11A00101  202206010500  202206020000  A02   2  109  2
# 3              3  11A00101  202206010500  202206021200  A02   3  109  2
# 4              4  11A00101  202206010500  202206030000  A02   4  109  2
# ...          ...       ...           ...           ...  ...  ..  ... ..
# 1603        1603  21F20804  202206010500  202206021200  A02   3  156  2
# 1604        1604  21F20804  202206010500  202206030000  A02   4  156  2
# 1605        1605  21F20804  202206010500  202206031200  A02   5  156  2
# 1606        1606  21F20804  202206010500  202206040000  A02   6  156  2
# 1607        1607  21F20804  202206010500  202206041200  A02   7  156  2
#
#      MAN_ID MAN_FC  W1  T  W2  TA  ST   SKY  PREP         WF
# ...

# %%
k
# Out:
#        Unnamed: 0         TM_FC         TM_EF         TM_IN  STN     REG_ID  \
# 0               0  202206011000  202206011000  202206010852  105   L1027020
# 1               1  202206011000  202206011000  202206010908  143   L1071300
# 2               2  202206031600  202206031600  202206031535  105   L1020110
# 3               3  202206031600  202206031600  202206031535  105   L1020210
# 4               4  202206031600  202206031600  202206031535  105   L1020300
# ...           ...           ...           ...           ...  ...        ...
# 21260       21260  202303122200  202303130000  202303122135  105   S1152020
# 21261       21261  202303122200  202303122300  202303122009  184   S1324210
# 21262       21262  202303130000  202303130000  202303122357  156   S1231300
# 21263       21263  202303130000  202303130000  202303122357  156   S1231400
# 21264       21264  202303130000  202303130000  202303122357  156   S1231500
#
#         WRN  LVL  CMD  GRD  CNT  RPT
# ...

# %%
g
# Out:
#         Unnamed: 0    YYMMDDHHMI   STN STN.1        LON       LAT     STN.2  \
# 0                0  202301010000    90    속초  128.56473  38.25085  000-----
# 1                1  202301010100    90    속초  128.56473  38.25085  000-----
# 2                2  202301010200    90    속초  128.56473  38.25085  000-----
# 3                3  202301010300    90    속초  128.56473  38.25085  000-----
# 4                4  202301010400    90    속초  128.56473  38.25085  000-----
# ...            ...           ...   ...   ...        ...       ...       ...
# 787705      787705  202303122000  5343    포항  129.37963  36.03259  000-----
# 787706      787706  202303122100  5343    포항  129.37963  36.03259  000-----
# 787707      787707  202303122200  5343    포항  129.37963  36.03259  000-----
# 787708      787708  202303122300  5343    포항  129.37963  36.03259  000-----
# 787709      787709  202303130000  5343    포항  129.37963  36.03259  000-----
#
# ...
